# %%
import pandas as pd

# create random sample from original embeddings file
# !shuf -n 25000 "./../data/cord_19_embeddings/cord_19_embeddings_2021-05-31.csv" > "./../data/cord_19_embeddings/small_cord_19_embeddings_2021-05-31.csv"

filename ='./../data/cord_19_embeddings/small_cord_19_embeddings_2021-05-31.csv'
embeddings = pd.read_csv(filename)

embeddings.head()
# Out:
#    rmvoi6kd  1.779409646987915  -2.2716519832611084  1.7611185312271118  \
# 0  csokkcqq          -0.803977            -5.319804           -1.840566
# 1  aegryc92          -2.205149            -6.059683            4.365172
# 2  bcnjn94w          -3.126923            -2.812798           -5.893511
# 3  wmbgpnr9          -2.617370            -6.451932            2.464819
# 4  4z2697q6          -1.998284            -5.829864           -0.389479
#
#    1.021221399307251  5.3017988204956055  -3.6000568866729736  \
# 0           7.307992           -0.178430            -0.837830
# 1           3.189713            0.064064             0.888921
# 2           2.878902            0.729707            -2.269688
# 3          -1.406574           -3.219028            -4.219977
# 4           7.124221           -1.730205            -2.596810
#
#    -0.8179324269294739  -0.7247124910354614  0.6504073739051819  ...  \
# 0            -1.684979             2.405927           -1.878175  ...
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

from sklearn.manifold import TSNE

m_tsne = TSNE(random_state=42, perplexity=30, n_components=2)
X_walk_tsne = m_tsne.fit_transform(embeddings.iloc[:, 1:])

plt.figure(figsize=(15, 15))
plt.scatter(X_walk_tsne[:, 0], X_walk_tsne[:, 1], s=10, alpha=0.5)
plt.show()
# Out:
# /home/jedi/.pyenv/39venv/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/jedi/.pyenv/39venv/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
